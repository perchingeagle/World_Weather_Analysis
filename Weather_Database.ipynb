# %%
import urllib
from datetime import datetime
import requests
import numpy as np
import pandas as pd
from citipy import citipy
from config import weather_api_key

# %%
lat = np.random.uniform(low=-90.0, high=90.0, size=2000)
lng = np.random.uniform(low=-180, high=180, size=2000)
lat_lng = zip(lat,lng)

# %%
cities = [citipy.nearest_city(item[0], item[1]).city_name for item in lat_lng]
#len(cities)

# %%
baseurl = 'http://api.openweathermap.org/data/2.5/weather?units={units}&APPID={api_key}'\
.format(units='Imperial', api_key=weather_api_key)

#{'units':'Imperial', 'APPID':weather_api_key}

# Empty dataframe created
#cities_df = pd.DataFrame(columns = ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Country', 'Date'])

# %%
cities_data = list()
skipped_cities = list()

print('Data retrieval: started')

for index, city in enumerate(list(cities)):
    url = ''.join((baseurl, '&q=', urllib.parse.quote(city)))
    try:
        response = requests.get(url)
        # if no data is returned
        if response.status_code == 200:
            data = response.json()
            
            cities_data.append({'City': city.title(),
                            'Lat': data["coord"]["lat"],
                            'Lng': data["coord"]["lon"],
                            'Max Temp': data["main"]["temp_max"],
                            'Humidity': data["main"]["humidity"],
                            'Cloudiness': data["clouds"]["all"],
                            'Wind Speed': data["wind"]["speed"],
                            'Country': data["sys"]["country"],
                            'Date': datetime.utcfromtimestamp(data["dt"]).strftime('%Y-%m-%d %H:%M:%S')})
        else:
            print(f'Status Code: {response.status_code}, {city} ({index}) skipped')
            skipped_cities.append((index, city))
    except:
        print(f'Error: {city} ({index}) skipped')
        skipped_cities.append((index, city))
        
print('Data retrieval: finished')
# Out:
# Data retrieval: started
# Status Code: 404, taolanaro (13) skipped
# Status Code: 404, toliary (37) skipped
# Status Code: 404, nizhneyansk (71) skipped
# Status Code: 404, tsihombe (76) skipped
# Status Code: 404, mys shmidta (140) skipped
# Status Code: 404, amderma (143) skipped
# Status Code: 404, belushya guba (158) skipped
# Status Code: 404, labutta (159) skipped
# Status Code: 404, lolua (162) skipped
# Status Code: 404, barentsburg (191) skipped
# Status Code: 404, taolanaro (199) skipped
# Status Code: 404, hihifo (203) skipped
# Status Code: 404, bababe (226) skipped
# Status Code: 404, illoqqortoormiut (240) skipped
# Status Code: 404, tumannyy (242) skipped
# Status Code: 404, mys shmidta (264) skipped
# Status Code: 404, nizhneyansk (268) skipped
# Status Code: 404, palabuhanratu (271) skipped
# Status Code: 404, barentsburg (274) skipped
# Status Code: 404, nizhneyansk (290) skipped
# Status Code: 404, belushya guba (296) skipped
# Status Code: 404, attawapiskat (307) skipped
# Status Code: 404, ruatoria (315) skipped
# Status Code: 404, umzimvubu (319) skipped
# Status Code: 404, sentyabrskiy (329) skipped
# Status Code: 404, taolanaro (331) skipped
# Status Code: 404, taolanaro (363) skipped
# Status Code: 404, barentsburg (371) skipped
# Status Code: 404, illoqqortoormiut (375) skipped
# Status Code: 404, nizhneyansk (376) skipped
# Status Code: 404, barentsburg (381) skipped
# Status Code: 404, burica (400) skipped
# Status Code: 404, warqla (415) skipped
# Status Code: 404, nizhneyansk (416) skipped
# Status Code: 404, mys shmidta (426) skipped
# Status Code: 404, taolanaro (1405) skipped
# Status Code: 404, barentsburg (1409) skipped
# Status Code: 404, taolanaro (1420) skipped
# Status Code: 404, tsihombe (1471) skipped
# Status Code: 404, grand river south east (1480) skipped
# Status Code: 404, tuggurt (1491) skipped
# Status Code: 404, taolanaro (1500) skipped
# Status Code: 404, louisbourg (1508) skipped
# Status Code: 404, belushya guba (1526) skipped
# Status Code: 404, belushya guba (1528) skipped
# Status Code: 404, illoqqortoormiut (1529) skipped
# Status Code: 404, belushya guba (1543) skipped
# Status Code: 404, amderma (1549) skipped
# Status Code: 404, palabuhanratu (1576) skipped
# Status Code: 404, andevoranto (1578) skipped
# Status Code: 404, shahpur city (1607) skipped
# Status Code: 404, illoqqortoormiut (1635) skipped
# Status Code: 404, grand river south east (1647) skipped
# Status Code: 404, taolanaro (1652) skipped
# Status Code: 404, mys shmidta (1685) skipped
# Status Code: 404, mys shmidta (1690) skipped
# Status Code: 404, grand river south east (1700) skipped
# Status Code: 404, amderma (1705) skipped
# Status Code: 404, marcona (1706) skipped
# Status Code: 404, palabuhanratu (1707) skipped
# Status Code: 404, ruatoria (1711) skipped
# Status Code: 404, taolanaro (1723) skipped
# Status Code: 404, vaitupu (1735) skipped
# Status Code: 404, lolua (1745) skipped
# Status Code: 404, azimur (1748) skipped
# Status Code: 404, illoqqortoormiut (1766) skipped
# Status Code: 404, taolanaro (1773) skipped
# Status Code: 404, taolanaro (1848) skipped
# Status Code: 404, attawapiskat (1870) skipped
# Status Code: 404, tsihombe (1872) skipped
# Status Code: 404, vaitupu (1876) skipped
# Status Code: 404, taolanaro (1891) skipped
# Status Code: 404, barentsburg (1892) skipped
# Status Code: 404, taolanaro (1895) skipped
# Status Code: 404, taolanaro (1900) skipped
# Status Code: 404, belushya guba (1902) skipped
# Status Code: 404, taolanaro (1925) skipped
# Status Code: 404, mys shmidta (1933) skipped
# Status Code: 404, rawannawi (1939) skipped
# Status Code: 404, azimur (1943) skipped
# Status Code: 404, ust-kamchatsk (1950) skipped
# Status Code: 404, barentsburg (1964) skipped
# Status Code: 404, taolanaro (1969) skipped
# Status Code: 404, illoqqortoormiut (1987) skipped
# Status Code: 404, mys shmidta (1994) skipped
# Status Code: 404, marcona (1995) skipped
# Data retrieval: finished

# %%
cities_df = pd.DataFrame(cities_data)
cities_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Yar-Sale  66.8333   70.8333     32.31        84          10
# 1         Khatanga  71.9667  102.5000     29.91        88          89
# 2  Bambous Virieux -20.3428   57.7575     70.21        76          22
# 3         Pimentel  -6.8367  -79.9342     63.45        87          18
# 4           Kodiak  57.7900 -152.4072     47.71        46          75
#
#    Wind Speed Country                 Date
# 0        6.91      RU  2021-09-26 01:21:42
# 1       10.80      RU  2021-09-26 01:12:21
# 2       16.58      MU  2021-09-26 01:20:18
# 3       14.05      PE  2021-09-26 01:21:42
# 4        4.61      US  2021-09-26 01:09:15

# %%
output_file = 'Weather_Database/Weather_Database.csv'
cities_df.to_csv(output_file, index_label="City_ID")
